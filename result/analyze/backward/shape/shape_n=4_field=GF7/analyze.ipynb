# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_grevlex = pd.read_csv('test.grevlex.csv', index_col=0)
df_grlex = pd.read_csv('test.grlex.csv', index_col=0)

# %%
df_grevlex.loc[df_grevlex['total_time'] <= 1.0]
# Out:
#      success  polynomial_additions  mono_div_steps  total_time  \
# 0       True                 22353          662856    0.202707
# 1       True                    57             164    0.004609
# 2       True                 36951         1534470    0.467058
# 3       True                 35051         1040547    0.332568
# 4       True                   132             322    0.005074
# ..       ...                   ...             ...         ...
# 994     True                 38143         1083129    0.946271
# 995     True                   995           13986    0.027955
# 997     True                   279            1215    0.006090
# 998     True                 17782          487354    0.449235
# 999     True                 11214          242174    0.241010
#
#      reduction_time  selection_time     variale_order  \
# 0          0.150419        0.021610  (x0, x1, x2, x3)
# 1          0.000216        0.000027  (x0, x1, x2, x3)
# ...

# %%
A = df_grevlex['polynomial_list'].to_numpy()
A[0]
# Out:
# '[2*x0*x1*x2*x3 - x0*x2^3 + 3*x0*x2^2*x3^3 + 2*x0*x2^2*x3^2 - 2*x0*x2^2*x3 - 3*x0*x2^2 + 2*x1^2*x2*x3 + x1^2*x2 + x1*x2*x3^5 - 3*x1*x2*x3^4 - 2*x1*x2*x3^2 + 2*x1*x2*x3 + 2*x1*x2 - 3*x2*x3^3 + 2*x3^6 + x3^3, 2*x0^3*x3 - 2*x0^3 + 3*x0^2*x3^5 + 2*x0^2*x3^4 + 2*x0^2*x3^3 - x0^2*x3 + x0^2 + 2*x0*x1^2*x2*x3^3 - x0*x1*x2^3*x3^2 + 3*x0*x1*x2^2*x3^5 + 2*x0*x1*x2^2*x3^4 - 2*x0*x1*x2^2*x3^3 - 3*x0*x1*x2^2*x3^2 + x0*x1*x2 - x0*x2*x3^4 - x0*x2*x3 + 2*x0*x2 + 2*x1^3*x2*x3^3 + x1^3*x2*x3^2 + x1^2*x2*x3^7 - 3*x1^2*x2*x3^6 - 2*x1^2*x2*x3^4 + 2*x1^2*x2*x3^3 + 2*x1^2*x2*x3^2 - 3*x1*x2*x3^5 + 2*x1*x3^8 + x1*x3^5 + x2 - 3*x3^3 - 2*x3^2 + 2*x3 + 3, 3*x0^5*x1*x3 - 3*x0^5*x1 + x0^4*x1*x3^5 + 3*x0^4*x1*x3^4 + 3*x0^4*x1*x3^3 + 2*x0^4*x1*x3 - 2*x0^4*x1 - 2*x0^3*x1^2*x2 + 2*x0^3*x1*x2*x3^4 + 2*x0^3*x1*x2*x3 + 3*x0^3*x1*x2 + 2*x0^2*x1^2*x2*x3 - x0^2*x1*x2^3 + 3*x0^2*x1*x2^2*x3^3 + 2*x0^2*x1*x2^2*x3^2 - 2*x0^2*x1*x2^2*x3 - 3*x0^2*x1*x2^2 - 2*x0^2*x1*x2 - x0^2*x1*x3^3 - 3*x0^2*x1*x3^2 + 3*x0^2*x1*x3 + x0^2*x1 - 2*
# ...

# %%
B = df_grevlex['F_G_str'].to_numpy()
B[0]
# Out:
# 'C2 E1 E1 E1 E1 + C6 E1 E0 E3 E0 + C3 E1 E0 E2 E3 + C2 E1 E0 E2 E2 + C5 E1 E0 E2 E1 + C4 E1 E0 E2 E0 + C2 E0 E2 E1 E1 + C1 E0 E2 E1 E0 + C1 E0 E1 E1 E5 + C4 E0 E1 E1 E4 + C5 E0 E1 E1 E2 + C2 E0 E1 E1 E1 + C2 E0 E1 E1 E0 + C4 E0 E0 E1 E3 + C2 E0 E0 E0 E6 + C1 E0 E0 E0 E3 [SEP] C2 E3 E0 E0 E1 + C5 E3 E0 E0 E0 + C3 E2 E0 E0 E5 + C2 E2 E0 E0 E4 + C2 E2 E0 E0 E3 + C6 E2 E0 E0 E1 + C1 E2 E0 E0 E0 + C2 E1 E2 E1 E3 + C6 E1 E1 E3 E2 + C3 E1 E1 E2 E5 + C2 E1 E1 E2 E4 + C5 E1 E1 E2 E3 + C4 E1 E1 E2 E2 + C1 E1 E1 E1 E0 + C6 E1 E0 E1 E4 + C6 E1 E0 E1 E1 + C2 E1 E0 E1 E0 + C2 E0 E3 E1 E3 + C1 E0 E3 E1 E2 + C1 E0 E2 E1 E7 + C4 E0 E2 E1 E6 + C5 E0 E2 E1 E4 + C2 E0 E2 E1 E3 + C2 E0 E2 E1 E2 + C4 E0 E1 E1 E5 + C2 E0 E1 E0 E8 + C1 E0 E1 E0 E5 + C1 E0 E0 E1 E0 + C4 E0 E0 E0 E3 + C5 E0 E0 E0 E2 + C2 E0 E0 E0 E1 + C3 E0 E0 E0 E0 [SEP] C3 E5 E1 E0 E1 + C4 E5 E1 E0 E0 + C1 E4 E1 E0 E5 + C3 E4 E1 E0 E4 + C3 E4 E1 E0 E3 + C2 E4 E1 E0 E1 + C5 E4 E1 E0 E0 + C5 E3 E2 E1 E0 + C2 E3 E1 E1 E4 + C2 E3 E1 E1 E1 + C3 
# ...
